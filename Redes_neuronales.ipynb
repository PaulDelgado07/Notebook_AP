# %% [markdown]
# ### Redes neuronales Convolucionales
#
# ## Por que surgieron las SNN?
# ImageNEt dataset
# - es un dataset de 15 millones de imanaes de alta resoluciones donde las imaagnes aproximadamente hay 20.000 categorias tambien las imaganes fueron obtenidos de internet y etiquetas por humanos.
#
# aqui viene la pregunta
# el softmax se la puede utilizar en los 15 millones de imaagnes?
# Obviamente que si porque no es binarias es un softmax
#
# ImageNet Large.Scale Visual Recognition Challenge (ILSVRC)
# - clasificacion de imagenes
# ![alt text](image.png)
#
# este clasifica las imaagnes de cual es su animal
#
# ![alt text](image-1.png)
#
# En este escenario el modelo estaba full entrenado porque hace multiple
#
# ### etiqutados de escenas
# ![alt text](image-2.png)
# aqui hay multiples etiquetas
#
# ### filtro
# ![alt text](image-3.png)
# eliminacion de ruido
#
# ### Visual Association Cortex
# Las neuronas individuales responde a estimulos solo en una region restringida del campo visual campo visual conocido como "campo receptivo".
#
# ![alt text](image-4.png)
#
# ### Problemas de imaganes
# En el dataset MNIST, una imagen en 28x28 pixiles en blanco y negro se representa como un vector de 748 elementos que corresponden con los elemento de la input layer de nuestra red
# ![alt text](image-5.png)
# Es un dataset con miles de fotos de numeros hechos por humanos donde el modelo debe aprender
#
# ![alt text](image-6.png)
# convertimos en .flatten(img) es por que la imagen lo guardamos en un vector. si se la convierte en estructura espacial
#
# ![alt text](image-7.png)
#
# ![alt text](image-8.png)
#
# ### que son las CNN
# ![alt text](image-9.png)
#
# ![alt text](image-10.png)
#
# ![alt text](image-11.png)
